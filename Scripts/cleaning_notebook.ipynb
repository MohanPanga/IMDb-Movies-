# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
file1 = '../Resources/world_country.csv'
file2 = '../Resources/filename.csv'

df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
# Out:
# /Users/mohanpanga/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df1.head(25)
list_1 = ['usa_state_code', 'usa_state_latitude', 'usa_state_longitude', 'usa_state']
df1.drop(list_1, axis=1,inplace=True)
#print(df1['country'].unique())

# %%
df2.head(5)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
df2.drop(['director', 'writer', 'production_company', 'description'], axis=1, inplace=True)

# %%
df2
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                                   actors  avg_vote  votes  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...       5.9    154
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...       6.1    589
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...       5.8    188
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...       5.2    446
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...       7.0   2237
# ...                                                  ...       ...    ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...       5.3    398
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...       7.7    724
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...       7.9    265
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...       6.4    194
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...       6.7    102
#
#         budget usa_gross_income worlwide_gross_income  metascore  \
# 0          NaN              NaN                   NaN        NaN
# 1       $ 2250              NaN                   NaN        NaN
# 2          NaN              NaN                   NaN        NaN
# 3      $ 45000              NaN                   NaN        NaN
# 4          NaN              NaN                   NaN        NaN
# ...        ...              ...                   ...        ...
# 85850      NaN              NaN             $ 3507171        NaN
# 85851      NaN              NaN             $ 7299062        NaN
# 85852      NaN              NaN                   NaN        NaN
# 85853      NaN              NaN                $ 2833        NaN
# 85854      NaN              NaN               $ 59794        NaN
#
#        reviews_from_users  reviews_from_critics
# 0                     1.0                   2.0
# 1                     7.0                   7.0
# 2                     5.0                   2.0
# 3                    25.0                   3.0
# 4                    31.0                  14.0
# ...                   ...                   ...
# 85850                 NaN                   4.0
# 85851                 6.0                   4.0
# 85852                 NaN                   NaN
# 85853                 NaN                   NaN
# 85854                 NaN                   2.0
#
# [85855 rows x 18 columns]

# %%
#df3 = df2.loc[df2['country'] == 'USA']
df2['country'] = df2['country'].replace('USA', 'United States')

df2.head(20)
# Out:
#    imdb_title_id                                              title  \
# 0      tt0000009                                         Miss Jerry
# 1      tt0000574                        The Story of the Kelly Gang
# 2      tt0001892                                     Den sorte drøm
# 3      tt0002101                                          Cleopatra
# 4      tt0002130                                          L'Inferno
# 5      tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 6      tt0002423                                     Madame DuBarry
# 7      tt0002445                                         Quo Vadis?
# 8      tt0002452                              Independenta Romaniei
# 9      tt0002461                                        Richard III
# 10     tt0002646                                           Atlantis
# 11     tt0002844              Fantômas - À l'ombre de la guillotine
# 12     tt0003014                           Il calvario di una madre
# 13     tt0003037                               Juve contre Fantômas
# 14     tt0003102                         Ma l'amor mio non muore...
# 15     tt0003131                             Maudite soit la guerre
# 16     tt0003165                                    Le mort qui tue
# 17     tt0003167                                     Amore di madre
# 18     tt0003419                               Lo studente di Praga
# 19     tt0003471                                   Traffic in Souls
#
#                                        original_title  year date_published  \
# 0                                          Miss Jerry  1894     1894-10-09
# 1                         The Story of the Kelly Gang  1906     1906-12-26
# 2                                      Den sorte drøm  1911     1911-08-19
# 3                                           Cleopatra  1912     1912-11-13
# 4                                           L'Inferno  1911     1911-03-06
# 5   From the Manger to the Cross; or, Jesus of Naz...  1912           1913
# 6                                      Madame DuBarry  1919     1919-11-26
# 7                                          Quo Vadis?  1913     1913-03-01
# 8                               Independenta Romaniei  1912     1912-09-01
# 9                                         Richard III  1912     1912-10-15
# 10                                           Atlantis  1913     1913-12-26
# 11              Fantômas - À l'ombre de la guillotine  1913     1913-05-12
# 12                                      Ingeborg Holm  1913     1915-10-18
# 13                               Juve contre Fantômas  1913     1913-09-08
# 14                         Ma l'amor mio non muore...  1914     1914-01-01
# 15                             Maudite soit la guerre  1914     1914-05-01
# 16                                    Le mort qui tue  1913     1913-11-06
# 17                                   Home, Sweet Home  1914     1914-05-17
# 18                               Der Student von Prag  1913     1913-08-22
# 19                                   Traffic in Souls  1913     1913-11-24
#
#                         genre  duration           country         language  \
# 0                     Romance        45     United States             None
# 1     Biography, Crime, Drama        70         Australia             None
# 2                       Drama        53  Germany, Denmark              NaN
# 3              Drama, History       100     United States          English
# 4   Adventure, Drama, Fantasy        68             Italy          Italian
# 5            Biography, Drama        60     United States          English
# 6   Biography, Drama, Romance        85           Germany           German
# 7              Drama, History       120             Italy          Italian
# 8                History, War       120           Romania              NaN
# 9                       Drama        55       France, USA          English
# 10                      Drama       121           Denmark           Danish
# 11               Crime, Drama        54            France           French
# 12                      Drama        96            Sweden              NaN
# 13               Crime, Drama        61            France           French
# 14                      Drama        90             Italy          Italian
# 15                 Drama, War        50           Belgium           French
# 16      Crime, Drama, Mystery        90            France           French
# 17                      Drama        55     United States          English
# 18     Drama, Fantasy, Horror        85           Germany  German, English
# 19               Crime, Drama        88     United States          English
#
#                                                actors  avg_vote  votes  \
# 0   Blanche Bayliss, William Courtenay, Chauncey D...       5.9    154
# 1   Elizabeth Tait, John Tait, Norman Campbell, Be...       6.1    589
# 2   Asta Nielsen, Valdemar Psilander, Gunnar Helse...       5.8    188
# 3   Helen Gardner, Pearl Sindelar, Miss Fielding, ...       5.2    446
# 4   Salvatore Papa, Arturo Pirovano, Giuseppe de L...       7.0   2237
# 5   R. Henderson Bland, Percy Dyer, Gene Gauntier,...       5.7    484
# 6   Pola Negri, Emil Jannings, Harry Liedtke, Edua...       6.8    753
# 7   Amleto Novelli, Gustavo Serena, Carlo Cattaneo...       6.2    273
# 8   Aristide Demetriade, Constanta Demetriade, Con...       6.7    198
# 9   Robert Gemp, Frederick Warde, Albert Gardner, ...       5.5    225
# 10  Olaf Fønss, Ida Orloff, Ebba Thomsen, Carl Lau...       6.6    331
# 11  René Navarre, Edmund Breon, Georges Melchior, ...       7.0   1944
# 12  Hilda Borgström, Aron Lindgren, Erik Lindholm,...       7.1    948
# 13  René Navarre, Edmund Breon, Georges Melchior, ...       7.0   1349
# 14  Lyda Borelli, Mario Bonnard, Gian Paolo Rosmin...       6.2    100
# 15  Baert, Suzanne Berni, Fernand Crommelynck, Nad...       6.5    124
# 16  René Navarre, Edmund Breon, Georges Melchior, ...       7.0   1050
# 17  Henry B. Walthall, Josephine Crowell, Lillian ...       5.8    187
# 18  Paul Wegener, Grete Berger, Lyda Salmonova, Jo...       6.5   1768
# 19  Jane Gail, Ethel Grandin, William H. Turner, M...       6.0    552
#
#         budget usa_gross_income worlwide_gross_income  metascore  \
# 0          NaN              NaN                   NaN        NaN
# 1       $ 2250              NaN                   NaN        NaN
# 2          NaN              NaN                   NaN        NaN
# 3      $ 45000              NaN                   NaN        NaN
# 4          NaN              NaN                   NaN        NaN
# 5          NaN              NaN                   NaN        NaN
# 6          NaN              NaN                   NaN        NaN
# 7    ITL 45000              NaN                   NaN        NaN
# 8   ROL 400000              NaN                   NaN        NaN
# 9      $ 30000              NaN                   NaN        NaN
# 10         NaN              NaN                   NaN        NaN
# 11         NaN              NaN                   NaN        NaN
# 12         NaN              NaN                   NaN        NaN
# 13         NaN              NaN                   NaN        NaN
# 14         NaN              NaN                   NaN        NaN
# 15         NaN              NaN                   NaN        NaN
# 16         NaN              NaN                   NaN        NaN
# 17         NaN              NaN                   NaN        NaN
# 18         NaN              NaN                   NaN        NaN
# 19      $ 5700              NaN                   NaN        NaN
#
#     reviews_from_users  reviews_from_critics
# 0                  1.0                   2.0
# 1                  7.0                   7.0
# 2                  5.0                   2.0
# 3                 25.0                   3.0
# 4                 31.0                  14.0
# 5                 13.0                   5.0
# 6                 12.0                   9.0
# 7                  7.0                   5.0
# 8                  4.0                   1.0
# 9                  8.0                   1.0
# 10                 9.0                   9.0
# 11                 9.0                  28.0
# 12                16.0                   7.0
# 13                 8.0                  23.0
# 14                 NaN                   4.0
# 15                 2.0                   2.0
# 16                 6.0                  18.0
# 17                 6.0                   NaN
# 18                20.0                  26.0
# 19                14.0                  11.0

# %%
#print(len(df3.budget.unique()))

# %%
df1.country.unique
# Out:
# <bound method Series.unique of 0                   Andorra
# 1      United Arab Emirates
# 2               Afghanistan
# 3       Antigua and Barbuda
# 4                  Anguilla
#                ...
# 240                   Yemen
# 241                 Mayotte
# 242            South Africa
# 243                  Zambia
# 244                Zimbabwe
# Name: country, Length: 245, dtype: object>

# %%
merged_df = pd.merge(df1,df2, on='country')

# %%
merged_df.drop(['date_published'], axis=1,inplace=True)
merged_df.head(20)
# Out:
#    country_code   latitude  longitude               country imdb_title_id  \
# 0            AE  23.424076  53.847818  United Arab Emirates     tt1159926
# 1            AE  23.424076  53.847818  United Arab Emirates     tt1663181
# 2            AE  23.424076  53.847818  United Arab Emirates     tt1770672
# 3            AE  23.424076  53.847818  United Arab Emirates     tt2184267
# 4            AE  23.424076  53.847818  United Arab Emirates     tt5314138
# 5            AE  23.424076  53.847818  United Arab Emirates     tt6200274
# 6            AE  23.424076  53.847818  United Arab Emirates     tt6840928
# 7            AE  23.424076  53.847818  United Arab Emirates     tt6890656
# 8            AE  23.424076  53.847818  United Arab Emirates     tt7741602
# 9            AE  23.424076  53.847818  United Arab Emirates     tt7834694
# 10           AE  23.424076  53.847818  United Arab Emirates     tt9279362
# 11           AL  41.153332  20.168331               Albania     tt0093720
# 12           AL  41.153332  20.168331               Albania     tt0170178
# 13           AL  41.153332  20.168331               Albania     tt0171564
# 14           AL  41.153332  20.168331               Albania     tt0173504
# 15           AL  41.153332  20.168331               Albania     tt0295730
# 16           AL  41.153332  20.168331               Albania    tt10102350
# 17           AL  41.153332  20.168331               Albania    tt11539888
# 18           AL  41.153332  20.168331               Albania     tt4307176
# 19           AL  41.153332  20.168331               Albania     tt5453036
#
#                      title          original_title  year  \
# 0             City of Life            City of Life  2009
# 1               Sea Shadow              Sea Shadow  2011
# 2                    Djinn                   Djinn  2013
# 3         Saint Dracula 3D        Saint Dracula 3D  2012
# 4                  Aerials                 Aerials  2016
# 5                  Hajwala                 Hajwala  2016
# 6        A Tale of Shadows       A Tale of Shadows  2017
# 7     If Something Happens    If Something Happens  2018
# 8           Until Midnight          Until Midnight  2018
# 9            Shabab Sheyab           Shabab Sheyab  2018
# 10                 11 Days                 11 Days  2018
# 11  Përralle Nga e Kaluara  Përralle Nga e Kaluara  1987
# 12      Lulekuqet mbi mure      Lulekuqet mbi mure  1976
# 13          Nëntori i dytë          Nëntori i dytë  1982
# 14        Zonja nga qyteti        Zonja nga qyteti  1976
# 15  Tomka dhe shokët e tij  Tomka dhe shokët e tij  1977
# 16          2 Gisht Mjaltë          2 Gisht Mjaltë  2019
# 17          I Love Tropoja          I Love Tropoja  2020
# 18             Pallati 176             Pallati 176  1986
# 19            Drejt Fundit            Drejt Fundit  2015
#
#                         genre  duration                language  \
# 0              Drama, Romance       119  Arabic, English, Hindi
# 1              Drama, Romance        98                  Arabic
# 2            Horror, Thriller        82         Arabic, English
# 3   Horror, Romance, Thriller       120                 English
# 4     Drama, Sci-Fi, Thriller        90         English, Arabic
# 5    Action, Adventure, Crime        96                  Arabic
# 6                    Thriller       107                 English
# 7                     Mystery        80                 English
# 8             Drama, Thriller        78         Arabic, English
# 9               Comedy, Drama        95                  Arabic
# 10                      Drama        85                  Arabic
# 11                     Comedy        86                Albanian
# 12                      Drama       100                Albanian
# 13                      Drama        93                Albanian
# 14    Comedy, Family, Romance       105                Albanian
# 15              Drama, Family        74                Albanian
# 16                     Comedy       101                Albanian
# 17          Adventure, Comedy       103                Albanian
# 18                     Comedy       115                Albanian
# 19                     Action       120                Albanian
#
#                                                actors  avg_vote  votes  \
# 0   Alexandra Maria Lara, Sonu Sood, Saoud Al Kaab...       6.9   1308
# 1   Omar Al Mulla, Neven Madi, Abrar Al Hamad, Kha...       6.3    181
# 2   Razane Jammal, Khalid Laith, Aiysha Hart, Abdu...       4.4   1686
# 3   Mitch Powell, Patricia Duarte, Anna Burkholder...       2.6    157
# 4   Saga Alyasery, Ana Druzhynina, Mansoor Alfeeli...       1.6    221
# 5   Anwar Aljabri, Haleem Aljabri, Omar Aljabri, A...       2.1    195
# 6   Angelica Narbut, Khaldoun Asfari, Mohamed Yahi...       5.9    132
# 7   Sofia Asir, Bronwyn Byrnes, Iain Colquhoun, La...       5.5    128
# 8   Ahmed Khamis Ali, Chuka Ekweogwu, Hiba Hamoui,...       7.6    578
# 9   Sad Al-Faraj, Salloum Haddad, Mansoor Alfeeli,...       7.8    377
# 10         Habib Ghuloom, Ahmed Hashimi, Imen Tablusi       8.5    618
# 11  Elvira Diamanti, Xhevdet Ferri, Mimika Luca, M...       7.8    191
# 12  Timo Flloko, Agim Qirjaqi, Kadri Roshi, Alfred...       8.3    192
# 13  Aleksandër Prosi, Bujar Lako, Reshat Arbana, V...       7.8    139
# 14  Violeta Manushi, Raimonda Bulku, Stavri Shkurt...       8.0    100
# 15  Sotiraq Çili, Pavlina Oça, Zehrudin Dokle, Xhe...       7.3    176
# 16  Margent Caushi, Bujar Asqeriu, Vin Bejleri, Ko...       3.2    561
# 17  Bujar Asqeriu, Margent Caushi, Julian Deda, Ar...       6.5    244
# 18  Eva Alikaj, Ilir Bezhani, Elida Janushi, Anast...       8.7    181
# 19  Drilon Hoxha, Erand Hoxha, Ardian Ramushi, Ard...       4.3    237
#
#           budget usa_gross_income worlwide_gross_income  metascore  \
# 0      $ 7500000              NaN              $ 647666        NaN
# 1            NaN              NaN                   NaN        NaN
# 2      $ 5000000              NaN                   NaN        NaN
# 3      $ 5000000              NaN                   NaN        NaN
# 4            NaN              NaN                $ 1124        NaN
# 5            NaN              NaN              $ 832186        NaN
# 6     AED 720000              NaN               $ 28551        NaN
# 7            NaN              NaN                   NaN        NaN
# 8     AED 450000              NaN                   NaN        NaN
# 9            NaN              NaN               $ 43564        NaN
# 10           $ 0              NaN                   NaN        NaN
# 11           NaN              NaN                   NaN        NaN
# 12           NaN              NaN                   NaN        NaN
# 13           NaN              NaN                   NaN        NaN
# 14           NaN              NaN                   NaN        NaN
# 15           NaN              NaN                   NaN        NaN
# 16    EUR 250000              NaN                   NaN        NaN
# 17  ALL 40000000              NaN                   NaN        NaN
# 18     ALL 10000              NaN                   NaN        NaN
# 19     EUR 85000              NaN                   NaN        NaN
#
#     reviews_from_users  reviews_from_critics
# 0                 14.0                   5.0
# 1                  2.0                   NaN
# 2                 15.0                  23.0
# 3                  1.0                   4.0
# 4                 36.0                   NaN
# 5                  7.0                   NaN
# 6                  4.0                   NaN
# 7                 13.0                   1.0
# 8                  4.0                   NaN
# 9                  2.0                   4.0
# 10                 2.0                   NaN
# 11                 1.0                   NaN
# 12                 2.0                   NaN
# 13                 NaN                   NaN
# 14                 NaN                   NaN
# 15                 2.0                   NaN
# 16                19.0                   2.0
# 17                13.0                   NaN
# 18                 NaN                   NaN
# 19                 4.0                   NaN

# %%
merged_df.shape
# Out:
# (64356, 20)

# %%
dftemp = merged_df.loc[merged_df['title'] == 'A Tale of Shadows']
dftemp
# Out:
#   country_code   latitude  longitude               country imdb_title_id  \
# 6           AE  23.424076  53.847818  United Arab Emirates     tt6840928
#
#                title     original_title  year     genre  duration language  \
# 6  A Tale of Shadows  A Tale of Shadows  2017  Thriller       107  English
#
#                                               actors  avg_vote  votes  \
# 6  Angelica Narbut, Khaldoun Asfari, Mohamed Yahi...       5.9    132
#
#        budget usa_gross_income worlwide_gross_income  metascore  \
# 6  AED 720000              NaN               $ 28551        NaN
#
#    reviews_from_users  reviews_from_critics
# 6                 4.0                   NaN

# %%
# merged_df.to_csv('../Resources/film_merged_table.csv',index=False)

# %%
merged_df
# Out:
#       country_code   latitude  longitude               country imdb_title_id  \
# 0               AE  23.424076  53.847818  United Arab Emirates     tt1159926
# 1               AE  23.424076  53.847818  United Arab Emirates     tt1663181
# 2               AE  23.424076  53.847818  United Arab Emirates     tt1770672
# 3               AE  23.424076  53.847818  United Arab Emirates     tt2184267
# 4               AE  23.424076  53.847818  United Arab Emirates     tt5314138
# ...            ...        ...        ...                   ...           ...
# 64351           ZA -30.559482  22.937506          South Africa     tt8038160
# 64352           ZA -30.559482  22.937506          South Africa     tt8047262
# 64353           ZA -30.559482  22.937506          South Africa     tt8595480
# 64354           ZA -30.559482  22.937506          South Africa     tt9102084
# 64355           ZW -19.015438  29.154857              Zimbabwe     tt7981318
#
#                   title    original_title  year                      genre  \
# 0          City of Life      City of Life  2009             Drama, Romance
# 1            Sea Shadow        Sea Shadow  2011             Drama, Romance
# 2                 Djinn             Djinn  2013           Horror, Thriller
# 3      Saint Dracula 3D  Saint Dracula 3D  2012  Horror, Romance, Thriller
# 4               Aerials           Aerials  2016    Drama, Sci-Fi, Thriller
# ...                 ...               ...   ...                        ...
# 64351          Stroomop          Stroomop  2018           Adventure, Drama
# 64352     The Tokoloshe     The Tokoloshe  2018           Horror, Thriller
# 64353            Canary            Canary  2018        Drama, Musical, War
# 64354       Fried Barry       Fried Barry  2020     Comedy, Horror, Sci-Fi
# 64355          Cook Off          Cook Off  2017            Comedy, Romance
#
#        duration                language  \
# 0           119  Arabic, English, Hindi
# 1            98                  Arabic
# 2            82         Arabic, English
# 3           120                 English
# 4            90         English, Arabic
# ...         ...                     ...
# 64351       106      Afrikaans, English
# 64352        92           English, Zulu
# 64353       123      Afrikaans, English
# 64354        99                 English
# 64355       101                 English
#
#                                                   actors  avg_vote  votes  \
# 0      Alexandra Maria Lara, Sonu Sood, Saoud Al Kaab...       6.9   1308
# 1      Omar Al Mulla, Neven Madi, Abrar Al Hamad, Kha...       6.3    181
# 2      Razane Jammal, Khalid Laith, Aiysha Hart, Abdu...       4.4   1686
# 3      Mitch Powell, Patricia Duarte, Anna Burkholder...       2.6    157
# 4      Saga Alyasery, Ana Druzhynina, Mansoor Alfeeli...       1.6    221
# ...                                                  ...       ...    ...
# 64351  DonnaLee Roberts, Simoné Pretorius, Chanelle d...       6.5    107
# 64352  Petronella Tshuma, Kwande Nkosi, Dawid Minnaar...       4.3    129
# 64353  Schalk Bezuidenhout, Hannes Otto, Germandt Gel...       7.7    363
# 64354  Gary Green, Brett Williams, Joey Cramer, Sean ...       6.5    113
# 64355  Tendaiishe Chitima, Tomas Brickhill, Chirikure...       6.0    256
#
#           budget usa_gross_income worlwide_gross_income  metascore  \
# 0      $ 7500000              NaN              $ 647666        NaN
# 1            NaN              NaN                   NaN        NaN
# 2      $ 5000000              NaN                   NaN        NaN
# 3      $ 5000000              NaN                   NaN        NaN
# 4            NaN              NaN                $ 1124        NaN
# ...          ...              ...                   ...        ...
# 64351        NaN              NaN              $ 501597        NaN
# 64352        NaN              NaN                   NaN        NaN
# 64353        NaN              NaN               $ 98665        NaN
# 64354        NaN              NaN                   NaN        NaN
# 64355        NaN              NaN                   NaN        NaN
#
#        reviews_from_users  reviews_from_critics
# 0                    14.0                   5.0
# 1                     2.0                   NaN
# 2                    15.0                  23.0
# 3                     1.0                   4.0
# 4                    36.0                   NaN
# ...                   ...                   ...
# 64351                 NaN                   2.0
# 64352                 5.0                  13.0
# 64353                 4.0                  13.0
# 64354                 1.0                  93.0
# 64355                26.0                   NaN
#
# [64356 rows x 20 columns]

# %%
engine = create_engine("postgresql://postgres:Redcherry@localhost:5432/Imdb")
conn = engine.connect()



merged_df.to_sql(name='world_films',con=conn,index=False)

# %%
merged_df["country"].nunique()
# Out:
# 118
